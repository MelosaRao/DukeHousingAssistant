# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util

# Load CSV
df = pd.read_csv('evaluation.csv', encoding='latin1')

# Load a sentence embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

def semantic_similarity(a, b):
    # Ensure inputs are strings before encoding
    a_str = str(a)
    b_str = str(b)
    emb1 = model.encode(a_str, convert_to_tensor=True)
    emb2 = model.encode(b_str, convert_to_tensor=True)
    return float(util.cos_sim(emb1, emb2))

# Compute similarity for each row
df["semantic_similarity"] = df.apply(
    lambda row: semantic_similarity(row["chat_answer"], row["my_answer"]),
    axis=1
)

df[["Question", "semantic_similarity"]]
# Out:
#                                              Question  semantic_similarity
# 0                     What is included in Edens dorm?             0.921590
# 1                           Who is the RC of randolph             0.945212
# 2                                 Who is Brandon Fain             1.000000
# 3   freshmen stay on west campus and others stay o...             0.732560
# 4                        How do I do laundry at duke?             0.936334
# 5                   i need help with mailing packages             0.601220
# 6   what address do i use for this. I live in blac...             0.854574
# 7      my ac is not working properly what should i do             0.599132
# 8                         how to submit a work order?             0.632222
# 9   it is 1.00 am i am locked out of my room what ...             0.590742
# 10  I am locked out at 10 am on monday what should...             0.566062
# ...

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util

# Ensure df is loaded and 'semantic_similarity' is available
# This makes the cell self-sufficient by reloading df and recomputing the necessary column.
# This assumes 'evaluation.csv' is available and contains 'chat_answer' and 'my_answer'.
df = pd.read_csv('evaluation.csv', encoding='latin1')
df = df.iloc[:15]

# Load a sentence embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

def semantic_similarity(a, b):
    # Ensure inputs are strings before encoding
    a_str = str(a)
    b_str = str(b)
    emb1 = model.encode(a_str, convert_to_tensor=True)
    emb2 = model.encode(b_str, convert_to_tensor=True)
    return float(util.cos_sim(emb1, emb2))

# Compute similarity for each row
df["semantic_similarity"] = df.apply(
    lambda row: semantic_similarity(row["chat_answer"], row["my_answer"]),
    axis=1
)

# Calculate the average of the semantic_similarity column
average_similarity = df['semantic_similarity'].mean()

# Display the average similarity
print(f"The average semantic similarity score is: {average_similarity:.4f}")
# Out:
# The average semantic similarity score is: 0.7059
